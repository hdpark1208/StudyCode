# %% [markdown]
# <a href="https://colab.research.google.com/github/hdpark1208/StudyCode/blob/main/Algorithm/BJ/DFS%EC%99%80_BFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DFS와 BFS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 입력 출력 및 예제

# %% [markdown]
# * 입력

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 출력

# %% [markdown]
# * 예제

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 구상

# %% [markdown]
# -

# %% [markdown]
# ## 코드

# %%
t = [[1,2,3], [5,4] ,[4,6,2]]
for i in t:
    i.sort()
    print(i)
print(t)
# Out:
# [1, 2, 3]
# [4, 5]
# [2, 4, 6]
# [[1, 2, 3], [4, 5], [2, 4, 6]]

# %%
t[1].append(2)
t
# Out:
# [[], [2], [], [], []]

# %%
from collections import deque

N, M, V = map(int,input().split())
graph = [[] for _ in range(N + 1)]
for _ in range(M):
    a, b = map(int, input().split())
    graph[a].append(b)
    graph[b].append(a)

for g in graph:
    g.sort()

visited = [False] * (N+1)
def dfs(g, v, visited):
    visited[v] = True
    print(v, end=' ')
    for i in graph[v]:
        if not visited[i]:
            dfs(g, i, visited)

dfs(graph, V, visited)

visited = [False] * (N+1)

def bfs(g, start, visited):
    queue = deque([start])
    visited[start] = True

    while queue:
        v = queue.popleft()
        print(v, end = ' ')
        for i in graph[v]:
            if not visited[i]:
                queue.append(i)
                visited[i] = True

print()
bfs(graph, V, visited)
# Out:
# 5 5 3
# 5 4
# 5 2
# 1 2
# 3 4
# 3 1
# 3 1 2 5 4
# 3 1 4 2 5

# %%
N = int(input())
S = [list(map(int, input().split())) for _ in range(N)]

team = [False]*N  # True: Start팀, False: Link팀
answer = float('inf')

def calc_diff():
    start_score, link_score = 0, 0

    # 능력치 계산
    for i in range(N):
        for j in range(i+1, N):
            if team[i] == team[j]:
                if team[i]:  # 둘 다 True → Start
                    start_score += S[i][j] + S[j][i]
                else:        # 둘 다 False → Link
                    link_score += S[i][j] + S[j][i]

    return abs(start_score - link_score)

def backtrack(idx):
    global answer

    if idx == N:
        # 두 팀 모두 최소 1명 이상 조건
        if 0 < sum(team) < N:
            diff = calc_diff()
            answer = min(answer, diff)
        return

    # i번 사람 Start 팀 포함
    team[idx] = True
    backtrack(idx + 1)

    # i번 사람 Link 팀 포함
    team[idx] = False
    backtrack(idx + 1)

backtrack(0)

print(answer)
# Out:
# 4
# 0 1 2 3
# 4 0 5 6
# 7 1 0 2
# 3 4 5 0
# 0

# %% [markdown]
# ### 메모
# - 입력이 많아 일일이 치기 귀찮을 때 꿀팁!

# %% [markdown]
# *

# %% [markdown]
# <a href="https://colab.research.google.com/github/hdpark1208/StudyCode/blob/main/Algorithm/BJ/%EB%B0%B1%EB%8F%84%EC%96%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 백도어

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 입력 출력 및 예제

# %% [markdown]
# * 입력

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 출력

# %% [markdown]
# * 예제

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 구상

# %% [markdown]
# - 시야에 걸리는 간선 제거

# %% [markdown]
# ## 코드

# %%
import heapq

N, M = map(int, input().split())
visible = list(map(int, input().split()))
visible[-1] = 0
graph = [[] for _ in range(N)]

for _ in range(M):
    a, b, c = map(int, input().split())
    if visible[a] != 1 and visible[b] != 1:
        graph[a].append((b,c))
        graph[b].append((a,c))

INF = float('inf')
dist = [INF] * N
dist[0] = 0

pq = []
heapq.heappush(pq, (0, 0))

while pq:

    cur_dist, now = heapq.heappop(pq)

    # 이미 해당 지점에 최소값이 있을 경우, 낭비하는 것 방지 # 이미 더 짧은 거리로 처리된 적 있으면 무시
    if cur_dist > dist[now]:
        continue

    # 내가 원했던 최적화
    if now == (N-1):
        print(cur_dist)
        break

    for nxt, cost in graph[now]:
        new_dist = cur_dist + cost

        if new_dist < dist[nxt]:
            dist[nxt] = new_dist
            heapq.heappush(pq, (new_dist, nxt))

if dist[-1] == INF:
    print('-1')
# Out:
# 5 7
# 0 0 0 1 1
# 0 1 7
# 0 2 2
# 1 2 4
# 1 3 3
# 1 4 6
# 2 3 2
# 3 4 1
# 12

# %%
0 2 2

# %%
# Out:
# [1, 2, 3, 4, 6, 8, 9, 10]

# %% [markdown]
# ### 메모

# %% [markdown]
# * https://www.acmicpc.net/problem/14284 와 거의 다를바 없었다

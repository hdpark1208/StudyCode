# %% [markdown]
# <a href="https://colab.research.google.com/github/hdpark1208/StudyCode/blob/main/Algorithm/BJ/11723_%EC%A7%91%ED%95%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 집합

# %% [markdown]
# 비어있는 공집합 S가 주어졌을 때, 아래 연산을 수행하는 프로그램을 작성하시오.
#
# - add x: S에 x를 추가한다. (1 ≤ x ≤ 20) S에 x가 이미 있는 경우에는 연산을 무시한다.
# - remove x: S에서 x를 제거한다. (1 ≤ x ≤ 20) S에 x가 없는 경우에는 연산을 무시한다.
# - check x: S에 x가 있으면 1을, 없으면 0을 출력한다. (1 ≤ x ≤ 20)
# - toggle x: S에 x가 있으면 x를 제거하고, 없으면 x를 추가한다. (1 ≤ x ≤ 20)
# - all: S를 {1, 2, ..., 20} 으로 바꾼다.
# - empty: S를 공집합으로 바꾼다.

# %% [markdown]
# ## 입력 출력 및 예제

# %% [markdown]
# * 입력

# %% [markdown]
# 첫째 줄에 수행해야 하는 연산의 수 M (1 ≤ M ≤ 3,000,000)이 주어진다.
#
# 둘째 줄부터 M개의 줄에 수행해야 하는 연산이 한 줄에 하나씩 주어진다.

# %% [markdown]
# * 출력

# %% [markdown]
# check 연산이 주어질때마다, 결과를 출력한다.

# %% [markdown]
# * 예제

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 구상

# %% [markdown]
# -

# %% [markdown]
# ## 코드

# %%
import sys

input = sys.stdin.readline
M = int(input())
s = set()

def process_command(command, *args):
    global s
    if command == "add":
        s.add(int(args[0]))
    elif command == "remove":
        s.discard(int(args[0]))
    elif command == "check":
        print(1 if int(args[0]) in s else 0)
    elif command == "toggle":
        x = int(args[0])
        if x in s:
            s.remove(x)
        else:
            s.add(x)
    elif command == "all":
        s = set(range(1, 21))
    elif command == "empty":
        s.clear()

for _ in range(M):
    parts = input().split()
    process_command(*parts)
# Out:
# {1}

# %%
# Out:
# 5 4 1 1
# 6

# %% [markdown]
# ### 메모

# %% [markdown]
# * 생각해보면 쉬운 문제였으나, 처음에 당황했다.

# %% [markdown]
# <a href="https://colab.research.google.com/github/hdpark1208/StudyCode/blob/main/Algorithm/BJ/23971_ZOAC_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ZOAC 4

# %% [markdown]
# 2021년 12월, 네 번째로 개최된 ZOAC의 오프닝을 맡은 성우는 오프라인 대회를 대비하여 강의실을 예약하려고 한다.
#
# 강의실에서 대회를 치르려면 거리두기 수칙을 지켜야 한다!
#
# 한 명씩 앉을 수 있는 테이블이 행마다 W개씩 H행에 걸쳐 있을 때, 모든 참가자는 세로로 N칸 또는 가로로 M칸 이상 비우고 앉아야 한다. 즉, 다른 모든 참가자와 세로줄 번호의 차가 N보다 크거나 가로줄 번호의 차가 M보다 큰 곳에만 앉을 수 있다.
#
# 논문과 과제에 시달리는 성우를 위해 강의실이 거리두기 수칙을 지키면서 최대 몇 명을 수용할 수 있는지 구해보자.

# %% [markdown]
# ## 입력 출력 및 예제

# %% [markdown]
# * 입력

# %% [markdown]
# H, W, N, M이 공백으로 구분되어 주어진다. (0 < H, W, N, M ≤ 50,000)

# %% [markdown]
# * 출력

# %% [markdown]
# 강의실이 수용할 수 있는 최대 인원 수를 출력한다.

# %% [markdown]
# * 예제

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 구상

# %% [markdown]
# - 참가자들은 일정하게 앉아야하고, 좌석의 형태도 직사각형으로 구분되니
# 각 행,열에 몇 명이 앉을 수 있는지만 알면 쉽게 구할수있을 것이다
# - 그 수를 어떻게 구할까
# - 참가자, 공백 자리를 묶어서. 올림!

# %% [markdown]
# ## 코드

# %%
import math

H, W, N, M = map(int, input().split())
count_h = math.ceil(H/(N+1))
count_w = math.ceil(W/(M+1))

print(count_h * count_w)
# Out:
# 5 4 1 1
# 6

# %% [markdown]
# ### 메모

# %% [markdown]
# * 생각해보면 쉬운 문제였으나, 처음에 당황했다.
